# %%
mylist = [1, 2, 3, 4, 5]
print(mylist)
# Out:
# [1, 2, 3, 4, 5]

# %%
from PIL import Image
from IPython.display import display

image = Image.open("data/jpg/R.jpeg")
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=850x550>

# %%
import numpy as np 
image_arr = np.array(image)
image_arr
# Out:
# array([[[140, 147, 140],
#         [145, 154, 149],
#         [151, 162, 158],
#         ...,
#         [103, 120, 114],
#         [104, 121, 115],
#         [104, 121, 115]],
#
#        [[134, 143, 138],
#         [143, 152, 149],
#         [149, 159, 158],
#         ...,
#         [ 94, 111, 105],
#         [ 95, 112, 106],
#         [ 94, 111, 105]],
#
#        [[135, 145, 144],
#         [143, 153, 152],
#         [149, 159, 160],
#         ...,
#         [ 95, 112, 104],
#         [ 96, 111, 106],
#         [ 95, 110, 105]],
#
#        ...,
#
#        [[108, 108,  98],
#         [107, 107,  97],
#         [107, 107,  97],
#         ...,
#         [169, 169, 171],
#         [168, 170, 169],
#         [168, 170, 169]],
#
#        [[111, 108,  99],
#         [109, 106,  97],
#         [109, 106,  97],
#         ...,
#         [165, 165, 167],
#         [161, 163, 162],
#         [161, 163, 162]],
#
#        [[111, 108,  99],
#         [110, 107,  98],
#         [110, 106,  97],
# ...

# %%
print(image_arr.shape)
print(image_arr.ndim)
# Out:
# (550, 850, 3)
# 3
